# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %%
import os
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
import time
import json
import numpy as np
from src import dataloader
from models import transformers, engine, configs

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Check if there is GPU(s): {torch.cuda.is_available()}")
# Out:
# Check if there is GPU(s): True

# %% [markdown]
# ### 4D

# %%
Exp_name  = 'test_v2'
data_loader_training, data_loader_validate, data_loader_testing = dataloader.return_data_loaders(configs.data_config_dict, configs.get_train_hyperparameter_config, Exp_name)
model      = transformers.VisionTransformer_V2(configs.SparkMET_4D_config_v2(), img_size=32, num_classes=2,).to(device)
loss_func  = torch.nn.NLLLoss() 
optimizer  = optim.Adam(model.parameters(), 
                        lr = configs.get_train_hyperparameter_config['lr'], 
                        weight_decay = configs.get_train_hyperparameter_config['wd'])
# Out:
# #================================ Summary of Dataset ==================#
# number of training samples:   52 | number of training fog cases:   7
# number of validation samples: 52 | number of validation fog cases: 7
# number of test samples:       52 | number of test fog cases:       7
# #======================================================================#

# %%
model, loss_stat = engine.train(model, optimizer, loss_func,
                                        configs.get_train_hyperparameter_config,
                                        data_loader_training, 
                                        data_loader_validate, 
                                        Exp_name)
# Out:
# Epoch 001: | Train Loss: 0.8855 | Val Loss: 0.7917 | Time(s): 25.184
# Best model Saved! Val Loss: 0.7917
# count: 0
# Epoch 002: | Train Loss: 0.5122 | Val Loss: 0.4840 | Time(s): 25.355
# Best model Saved! Val Loss: 0.4840
# count: 0
# Epoch 003: | Train Loss: 0.5455 | Val Loss: 0.5304 | Time(s): 25.553
# Model is not saved! Current Val Loss: 0.5304
# count: 1
# Epoch 004: | Train Loss: 0.4227 | Val Loss: 0.5761 | Time(s): 25.007
# Model is not saved! Current Val Loss: 0.5761
# count: 2
# Epoch 005: | Train Loss: 0.5495 | Val Loss: 0.5924 | Time(s): 24.351
# Model is not saved! Current Val Loss: 0.5924
# count: 3
# Epoch 006: | Train Loss: 0.4164 | Val Loss: 0.4983 | Time(s): 25.651
# Model is not saved! Current Val Loss: 0.4983
# count: 4
# Epoch 007: | Train Loss: 0.3731 | Val Loss: 0.4394 | Time(s): 26.967
# Best model Saved! Val Loss: 0.4394
# count: 0
# Epoch 008: | Train Loss: 0.3360 | Val Loss: 0.3808 | Time(s): 24.792
# Best model Saved! Val Loss: 0.3808
# count: 0
# Epoch 009: | Train Loss: 0.3519 | Val Loss: 0.5893 | Time(s): 24.453
# Model is not saved! Current Val Loss: 0.5893
# count: 1
# Epoch 010: | Train Loss: 0.4215 | Val Loss: 0.3972 | Time(s): 24.416
# Model is not saved! Current Val Loss: 0.3972
# count: 2
# Epoch 011: | Train Loss: 0.3467 | Val Loss: 0.3917 | Time(s): 25.619
# Model is not saved! Current Val Loss: 0.3917
# count: 3
# Epoch 012: | Train Loss: 0.3442 | Val Loss: 0.3560 | Time(s): 24.606
# Best model Saved! Val Loss: 0.3560
# count: 0
# Epoch 013: | Train Loss: 0.2938 | Val Loss: 0.2539 | Time(s): 30.419
# Best model Saved! Val Loss: 0.2539
# count: 0
# Epoch 014: | Train Loss: 0.2181 | Val Loss: 0.1286 | Time(s): 28.391
# Best model Saved! Val Loss: 0.1286
# count: 0
# Epoch 015: | Train Loss: 0.1103 | Val Loss: 2.2492 | Time(s): 28.925
# Model is not saved! Current Val Loss: 2.2492
# count: 1
# Epoch 016: | Train Loss: 1.1385 | Val Loss: 0.4156 | Time(s): 25.741
# Model is not saved! Current Val Loss: 0.4156
# count: 2
# Epoch 017: | Train Loss: 0.3141 | Val Loss: 0.4709 | Time(s): 24.688
# Model is not saved! Current Val Loss: 0.4709
# count: 3
# Epoch 018: | Train Loss: 0.3319 | Val Loss: 0.3218 | Time(s): 23.981
# Model is not saved! Current Val Loss: 0.3218
# count: 4
# Epoch 019: | Train Loss: 0.2923 | Val Loss: 0.4281 | Time(s): 25.098
# Model is not saved! Current Val Loss: 0.4281
# count: 5
# Epoch 020: | Train Loss: 0.3637 | Val Loss: 0.2267 | Time(s): 26.072
# Model is not saved! Current Val Loss: 0.2267
# count: 6
# Epoch 021: | Train Loss: 0.3054 | Val Loss: 0.5357 | Time(s): 29.951
# Model is not saved! Current Val Loss: 0.5357
# count: 7
# Epoch 022: | Train Loss: 0.5789 | Val Loss: 0.4241 | Time(s): 24.764
# Model is not saved! Current Val Loss: 0.4241
# count: 8
# Epoch 023: | Train Loss: 0.2351 | Val Loss: 0.7033 | Time(s): 24.475
# Model is not saved! Current Val Loss: 0.7033
# count: 9
# Epoch 024: | Train Loss: 0.5609 | Val Loss: 0.7422 | Time(s): 25.572
# Model is not saved! Current Val Loss: 0.7422
# count: 10
# Epoch 025: | Train Loss: 0.5328 | Val Loss: 0.7176 | Time(s): 24.445
# Model is not saved! Current Val Loss: 0.7176
# count: 11
# Epoch 026: | Train Loss: 0.5046 | Val Loss: 0.4379 | Time(s): 26.950
# Model is not saved! Current Val Loss: 0.4379
# count: 12
# Epoch 027: | Train Loss: 0.3523 | Val Loss: 0.4272 | Time(s): 24.697
# Model is not saved! Current Val Loss: 0.4272
# count: 13
# Epoch 028: | Train Loss: 0.3537 | Val Loss: 0.2672 | Time(s): 25.073
# Model is not saved! Current Val Loss: 0.2672
# count: 14
# Epoch 029: | Train Loss: 0.2360 | Val Loss: 0.2995 | Time(s): 29.503
# Model is not saved! Current Val Loss: 0.2995
# count: 15
# Epoch 030: | Train Loss: 0.1994 | Val Loss: 0.0887 | Time(s): 24.288
# Best model Saved! Val Loss: 0.0887
# count: 0
# Epoch 031: | Train Loss: 0.1206 | Val Loss: 0.0774 | Time(s): 24.506
# Best model Saved! Val Loss: 0.0774
# count: 0
# Epoch 032: | Train Loss: 0.2857 | Val Loss: 0.3108 | Time(s): 29.497
# Model is not saved! Current Val Loss: 0.3108
# count: 1
# Epoch 033: | Train Loss: 0.2666 | Val Loss: 0.1714 | Time(s): 28.606
# Model is not saved! Current Val Loss: 0.1714
# count: 2
# Epoch 034: | Train Loss: 0.1532 | Val Loss: 0.1064 | Time(s): 30.820
# Model is not saved! Current Val Loss: 0.1064
# count: 3
# Epoch 035: | Train Loss: 0.1660 | Val Loss: 0.0993 | Time(s): 25.396
# Model is not saved! Current Val Loss: 0.0993
# count: 4
# Epoch 036: | Train Loss: 0.0931 | Val Loss: 0.0845 | Time(s): 24.695
# Model is not saved! Current Val Loss: 0.0845
# count: 5
# Epoch 037: | Train Loss: 0.0591 | Val Loss: 0.0358 | Time(s): 26.408
# Best model Saved! Val Loss: 0.0358
# count: 0
# Epoch 038: | Train Loss: 0.0288 | Val Loss: 0.0100 | Time(s): 28.966
# Best model Saved! Val Loss: 0.0100
# count: 0
# Epoch 039: | Train Loss: 0.0125 | Val Loss: 0.0156 | Time(s): 29.391
# Model is not saved! Current Val Loss: 0.0156
# count: 1
# Epoch 040: | Train Loss: 0.0077 | Val Loss: 0.0017 | Time(s): 24.447
# Best model Saved! Val Loss: 0.0017
# count: 0
# Epoch 041: | Train Loss: 0.0013 | Val Loss: 0.0007 | Time(s): 28.519
# Best model Saved! Val Loss: 0.0007
# count: 0
# Epoch 042: | Train Loss: 0.0006 | Val Loss: 0.0006 | Time(s): 25.504
# Best model Saved! Val Loss: 0.0006
# count: 0
# Epoch 043: | Train Loss: 0.0005 | Val Loss: 0.0013 | Time(s): 29.305
# Model is not saved! Current Val Loss: 0.0013
# count: 1
# Epoch 044: | Train Loss: 0.0018 | Val Loss: 0.0009 | Time(s): 27.925
# Model is not saved! Current Val Loss: 0.0009
# count: 2
# Epoch 045: | Train Loss: 0.0038 | Val Loss: 0.0166 | Time(s): 27.868
# Model is not saved! Current Val Loss: 0.0166
# count: 3
# Epoch 046: | Train Loss: 0.0231 | Val Loss: 0.3781 | Time(s): 25.039
# Model is not saved! Current Val Loss: 0.3781
# count: 4
# Epoch 047: | Train Loss: 0.0968 | Val Loss: 0.5042 | Time(s): 25.936
# Model is not saved! Current Val Loss: 0.5042
# count: 5
# Epoch 048: | Train Loss: 0.3033 | Val Loss: 0.3146 | Time(s): 26.057
# Model is not saved! Current Val Loss: 0.3146
# count: 6
# Epoch 049: | Train Loss: 0.1986 | Val Loss: 0.5267 | Time(s): 28.041
# Model is not saved! Current Val Loss: 0.5267
# count: 7
# Epoch 050: | Train Loss: 0.2674 | Val Loss: 0.4270 | Time(s): 26.396
# Model is not saved! Current Val Loss: 0.4270
# count: 8

# %%
list_predictions, list_inputs, list_raw_attentio_scores, list_attention_gen_maps, list_attention_calc_scores = engine.predict(model, 
                                                data_loader_training, 
                                                data_loader_validate, 
                                                data_loader_testing, 
                                                Exp_name = Exp_name,)

# %%
list_raw_attentio_scores[0].shape
# Out:
# (52, 8, 388, 388, 6)

# %%
corr_values = list_raw_attentio_scores[0][idx, 7, :, :, 5]
corr_values = (corr_values)/(corr_values.max(axis=1))
for j in range(corr_values.shape[1]): 
    this_col_max = corr_values[:, j].max()
    this_col_min = corr_values[:, j].min()
    corr_values[:, j] = (corr_values[:, j] - this_col_min)/(this_col_max - this_col_min)
corr_values
# Out:
# array([[0.1012432 , 0.09753267, 0.09742086, ..., 0.9111744 , 0.9135283 ,
#         0.9214673 ],
#        [0.10461526, 0.09777696, 0.09760421, ..., 0.920848  , 0.9252089 ,
#         0.9396193 ],
#        [0.1088405 , 0.10180774, 0.10157683, ..., 0.9173221 , 0.9217665 ,
#         0.9364049 ],
#        ...,
#        [0.51344764, 0.50280935, 0.5025058 , ..., 0.50257665, 0.5094151 ,
#         0.5398966 ],
#        [0.5257171 , 0.5130084 , 0.51265126, ..., 0.49726516, 0.50497234,
#         0.53838396],
#        [0.5576501 , 0.5430561 , 0.5426598 , ..., 0.4777371 , 0.4871131 ,
#         0.5243918 ]], dtype=float32)

# %%
from sklearn.preprocessing import normalize
corr_values = list_raw_attentio_scores[0][idx, 7, :, :, 5]
data = normalize(corr_values, axis=1, norm='max')
data.min()
# Out:
# 0.9946762

# %%
idx = list_predictions[0][list_predictions[0]['date_cycletime'] =='20200115_0000'].index[0]
#corr_values = list_raw_attentio_scores[0][idx, 7, :, :, 5]
#corr_values = (corr_values - corr_values.min(axis=0))/(corr_values.max(axis=0) -  corr_values.min(axis=0))
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, figsize = (24, 24))

vis1 = ax.imshow(corr_values)
#vis1.set_clim(0.002565,0.002570)
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
cbar1 = fig.colorbar(vis1, cax=cax)

# %%
idx = list_predictions[0][list_predictions[0]['date_cycletime'] =='20200115_0000'].index[0]
corr_values = list_raw_attentio_scores[0][idx, 7, :, :, 5]
corr_values = corr_values / corr_values.max(axis=0)
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, figsize = (24, 24))

vis1 = ax.imshow(corr_values)
vis1.set_clim(0.002565,0.002570)
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
cbar1 = fig.colorbar(vis1, cax=cax)

# %%
def return_variables_corr(attention_scores, date:str, sum_heads: True): 

    idx = list_output[0][list_output[0]['date_cycletime'] ==date].index[0]


    sum_scores = np.zeros(attention_scores.shape[2])
    if sum_heads is True: 
        for head in range(list_attention_maps[0].shape[1]):
            this_head_scores = list_attention_maps[0][idx, head, :, -1]
            sum_scores += this_head_scores

        #[i[0] for i in sorted(enumerate(this_head_scores), key=lambda k: k[1], reverse=True)]
        avg_scores = sum_scores/list_attention_maps[0].shape[1]
        inxs = [i[0] for i in sorted(enumerate(avg_scores), key=lambda k: k[1], reverse=True)]

    ids = [(idx - ((idx//97)*97)) for idx in inxs]
    variables_dict = {}
    for idx in inxs: 
        id = (idx - ((idx//97)*97))
        t = (idx//97)
        if id < 93: 
            variables = configs.NETCDF_PREDICTOR_NAMES['All'][id]
        elif id == 93:
            variables = configs.NETCDF_SST
        elif id == 94:
            variables = configs.NETCDF_TMPDPT
        elif id == 95:
            variables = configs.NETCDF_TMPSST
        elif id == 96:
            variables = configs.NETCDF_DPTSST

        variables_dict[variables] = [idx, t]
    return variables_dict

# %%
out_dict = return_variables_corr(list_attention_maps[0], date = '20200115_0000', sum_heads = True)
out_dict
# Out:
# {'VGRD_700mb': [341, 3],
#  'UGRD_950mb': [213, 2],
#  'UGRD_10maboveground': [304, 3],
#  'RH_700mb': [75, 0],
#  'Q_725mb': [256, 2],
#  'UGRD_925mb': [22, 0],
#  'RH_725mb': [268, 2],
#  'UGRD_775mb': [331, 3],
#  'Q_775mb': [157, 1],
#  'Q_750mb': [255, 2],
#  'RH_825mb': [361, 3],
#  'UGRD_825mb': [325, 3],
#  'UGRD_750mb': [334, 3],
#  'UGRD_800mb': [328, 3],
#  'RH_750mb': [267, 2],
#  'UGRD_900mb': [316, 3],
#  'Q_800mb': [156, 1],
#  'VGRD_725mb': [241, 2],
#  'Q_825mb': [349, 3],
#  'RH_900mb': [358, 3],
#  'UGRD_850mb': [322, 3],
#  'TMP_750mb': [10, 0],
#  'RH_850mb': [360, 3],
#  'RH_800mb': [362, 3],
#  'RH_775mb': [72, 0],
#  'TMP_775mb': [9, 0],
#  'RH_925mb': [357, 3],
#  'TMP_950mb': [196, 2],
#  'TMP_925mb': [197, 2],
#  'RH_950mb': [259, 2],
#  'TMP_800mb': [8, 0],
#  'Q_700mb': [354, 3],
#  'TMP_725mb': [205, 2],
#  'TKE_825mb': [327, 3],
#  'RH_975mb': [64, 0],
#  'TMP_975mb': [195, 2],
#  'Q_925mb': [151, 1],
#  'VVEL_875mb': [182, 1],
#  'VGRD_950mb': [20, 0],
#  'Q_975mb': [52, 0],
#  'TMP_850mb': [297, 3],
#  'TMP_825mb': [7, 0],
#  'TKE_700mb': [245, 2],
#  'TMP_900mb': [198, 2],
#  'TMP_875mb': [296, 3],
#  'Q_850mb': [348, 3],
#  'VGRD_975mb': [17, 0],
#  'VGRD_10maboveground': [305, 3],
#  'DPT_2maboveground': [76, 0],
#  'LCLT': [79, 0],
#  'Q_950mb': [150, 1],
#  'Q_surface': [77, 0],
#  'Q_900mb': [346, 3],
#  'UGRD_875mb': [319, 3],
#  'VVEL_900mb': [181, 1],
#  'TKE_800mb': [136, 1],
#  'Q_875mb': [347, 3],
#  'TMP_700mb': [206, 2],
#  'RH_875mb': [359, 3],
#  'VVEL_850mb': [183, 1],
#  'RH_2maboveground': [78, 0],
#  'TKE_725mb': [145, 1],
#  'VGRD_925mb': [23, 0],
#  'TKE_750mb': [142, 1],
#  'UGRD_975mb': [113, 1],
#  'TKE_775mb': [139, 1],
#  'VVEL_700mb': [286, 2],
#  'VGRD_800mb': [329, 3],
#  'VGRD_775mb': [332, 3],
#  'VVEL_825mb': [184, 1],
#  'VGRD_750mb': [238, 2],
#  'VGRD_825mb': [326, 3],
#  'VVEL_800mb': [185, 1],
#  'VVEL_725mb': [285, 2],
#  'TMP_2maboveground': [291, 3],
#  'VVEL_775mb': [283, 2],
#  'VVEL_750mb': [284, 2],
#  'VGRD_900mb': [26, 0],
#  'VGRD_850mb': [323, 3],
#  'VVEL_925mb': [180, 1],
#  'VGRD_875mb': [320, 3],
#  'VVEL_950mb': [276, 2],
#  'VVEL_975mb': [275, 2],
#  'TMP-SST': [386, 3],
#  'DPT-SST': [290, 2],
#  'UGRD_725mb': [337, 3],
#  'FRICV_surface': [306, 3],
#  'UGRD_700mb': [340, 3],
#  'analysed_sst': [384, 3],
#  'VIS_surface': [274, 2],
#  'TKE_975mb': [18, 0],
#  'TKE_950mb': [312, 3],
#  'TKE_925mb': [315, 3],
#  'TKE_900mb': [124, 1],
#  'TKE_875mb': [127, 1],
#  'TMP-DPT': [385, 3],
#  'TKE_850mb': [33, 0]}

# %%
_ = engine.attention_map_visualize(list_output[0], list_inputs[0], list_attention_maps[0], variable = 93, date = '20200115_0000')

# %%
_ = engine.attention_map_guassian_visualize(list_output[0], list_inputs[0], list_attention_scores[0], variable = 93, date = '20200115_0000')
